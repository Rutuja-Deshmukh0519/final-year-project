# %%
import pandas as pd

# %%
pd.read_csv("D:/Documents/Final Year Sem VII/DMW miniproj/train.csv")
# Out:
#           Id  game_seq  season_end        date  season_game_seq  playoff  \
# 0          1     39323        1997   11/2/1996                2    False
# 1          2     59211        2012   6/17/2012               87     True
# 2          3     60691        2014  11/20/2013               12    False
# 3          4     31900        1990   3/29/1990               69    False
# 4          5     48134        2004    1/2/2004               30    False
# ...      ...       ...         ...         ...              ...      ...
# 44995  44996     53096        2008  11/28/2007               14    False
# 44996  44997     21870        1981  10/18/1980                4    False
# 44997  44998     49471        2005   1/14/2005               38    False
# 44998  44999     39193        1996   4/17/1996               80    False
# 44999  45000     34095        1992    3/3/1992               57    False
#
#       team_id        Elo opp_team_id    opp_Elo  win_equivalent  bet_ratio  \
# ...
